# %%
import h5py
import requests
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
key = "api_key.txt"

with open(key) as file :
    api_key = file.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 key = "api_key.txt"
# ----> 3 with open(key) as file :
#       4     api_key = file.read()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'api_key.txt'

# %%
baseUrl = 'http://www.tng-project.org/api/'
headers = {"api-key":f"{api_key}"}

def get(path, params=None):
    # make HTTP GET request to path
    r = requests.get(path, params=params, headers=headers)

    # raise exception if response code is not HTTP SUCCESS (200)
    r.raise_for_status()

    if r.headers['content-type'] == 'application/json':
        return r.json() # parse json responses automatically
    
    if 'content-disposition' in r.headers:
        filename = r.headers['content-disposition'].split("filename=")[1]
        with open(filename, 'wb') as f:
            f.write(r.content)
        return filename # return the filename string
    
    return r

# %%
data = np.load("../data/simulations/tng300-1_z0_positions.npz")
pos = np.column_stack([data["x_pos"], data["y_pos"], data["z_pos"]])
print("loaded", len(pos), "subhalos")
# Out:
# loaded 14485709 subhalos

# %%
np.random.seed(42)

n_data = 5000
idx = np.random.choice(len(pos), size=min(n_data, len(pos)), replace=False)
data_points = pos[idx]

boxsize = 302600 
n_random = 3 * len(data_points)
random_points = np.random.rand(n_random, 3) * boxsize

#need to have same dimensionality in y and z
bins = np.linspace(0.1, 1, 100) * boxsize

def count_pairs(points1, points2, bins):
    pair_counts = np.zeros(len(bins) - 1)
    
    for i in range(len(points1)):
        distances_sq = np.sum((points1[i] - points2) ** 2, axis=1)
        counts, _ = np.histogram(np.sqrt(distances_sq), bins = bins)
        pair_counts += counts

    return pair_counts
        
dd = count_pairs(data_points, data_points, bins)
dr = count_pairs(data_points, random_points, bins)
rr = count_pairs(random_points, random_points, bins)


#get the num of points in each catalog
nD = len(data_points)
nR = len(random_points)

dd = dd / (nD * (nD - 1)/2)
dr = dr / (nD * nR)
rr = rr / (nR * (nR - 1)/2)

# %%
xi_all = []
n_repeat = 30

for k in range(n_repeat):
    idx = np.random.choice(len(pos), size=n_data, replace=False)
    data_points = pos[idx]
    nD = len(data_points)

    dd = count_pairs(data_points, data_points,   bins)
    dr = count_pairs(data_points, random_points, bins)
    dd = dd / (nD * (nD - 1)/2)
    dr = dr / (nD * nR)

    # COMPUTE THE 2PCF USING LANDY-SZALAY ESTIMATOR
    xi = np.zeros_like(dd, dtype=float)
    valid_bins = rr != 0
    xi[valid_bins] = (dd[valid_bins] - 2 * dr[valid_bins] + rr[valid_bins]) / rr[valid_bins]
    xi[~valid_bins] = np.nan
    xi_all.append(xi)

xi_all = np.array(xi_all)          # shape (n_repeat, n_bins)

# %%
centers = 0.5 * (bins[:-1] + bins[1:])

xi_mean = np.nanmean(xi_all, axis=0)
xi_lo   = np.nanpercentile(xi_all, 5,  axis=0)
xi_hi   = np.nanpercentile(xi_all, 95, axis=0)

plt.figure(figsize=(8, 5))
plt.fill_between(centers, xi_lo, xi_hi, alpha=0.3, label="5th–95th percentile")
plt.plot(centers, xi_mean, "o-", label="mean", markersize = 1)
plt.axhline(0, color="gray", ls="--", lw=1)
plt.xlabel("r [ckpc/h]")
plt.ylabel(r"$\xi(r)$")
plt.title(f"2PCF: {n_repeat} resamples of {n_data} subhalos")
plt.legend()
plt.show()

# %%
#try another version with 10000 subhalos, confirm that increasing subhalo concentration doesnt affect 2pcf
#need some sort of machine vision to classify voids

# %%
np.random.seed(42)

n_data = 10000
idx = np.random.choice(len(pos), size=min(n_data, len(pos)), replace=False)
data_points = pos[idx]

boxsize = 302600   # Illustris box = 75 Mpc/h = 75000 ckpc/h
n_random = 3 * len(data_points)
random_points = np.random.rand(n_random, 3) * boxsize

#need to have same dimensionality in y and z
bins = np.linspace(0.1, 1, 100) * boxsize

def count_pairs(points1, points2, bins):
    pair_counts = np.zeros(len(bins) - 1)
    
    for i in range(len(points1)):
        distances_sq = np.sum((points1[i] - points2) ** 2, axis=1)
        counts, _ = np.histogram(np.sqrt(distances_sq), bins = bins)
        pair_counts += counts

    return pair_counts
        
dd = count_pairs(data_points, data_points, bins)
dr = count_pairs(data_points, random_points, bins)
rr = count_pairs(random_points, random_points, bins)


#get the num of points in each catalog
nD = len(data_points)
nR = len(random_points)

dd = dd / (nD * (nD - 1)/2)
dr = dr / (nD * nR)
rr = rr / (nR * (nR - 1)/2)

# %%
xi_all = []
n_repeat = 30

for k in range(n_repeat):
    idx = np.random.choice(len(pos), size=n_data, replace=False)
    data_points = pos[idx]
    nD = len(data_points)

    dd = count_pairs(data_points, data_points,   bins)
    dr = count_pairs(data_points, random_points, bins)
    dd = dd / (nD * (nD - 1)/2)
    dr = dr / (nD * nR)

    # COMPUTE THE 2PCF USING LANDY-SZALAY ESTIMATOR
    xi = np.zeros_like(dd, dtype=float)
    valid_bins = rr != 0
    xi[valid_bins] = (dd[valid_bins] - 2 * dr[valid_bins] + rr[valid_bins]) / rr[valid_bins]
    xi[~valid_bins] = np.nan
    xi_all.append(xi)

xi_all = np.array(xi_all)          # shape (n_repeat, n_bins)

# %%
centers = 0.5 * (bins[:-1] + bins[1:])

xi_mean = np.nanmean(xi_all, axis=0)
xi_lo   = np.nanpercentile(xi_all, 5,  axis=0)
xi_hi   = np.nanpercentile(xi_all, 95, axis=0)

plt.figure(figsize=(8, 5))
plt.fill_between(centers, xi_lo, xi_hi, alpha=0.3, label="5th–95th percentile")
plt.plot(centers, xi_mean, "o-", label="mean")
plt.axhline(0, color="gray", ls="--", lw=1)
plt.xlabel("r [ckpc/h]")
plt.ylabel(r"$\xi(r)$")
plt.title(f"2PCF: {n_repeat} resamples of {n_data} subhalos")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 centers = 0.5 * (bins[:-1] + bins[1:])
#       3 xi_mean = np.nanmean(xi_all, axis=0)
#       4 xi_lo   = np.nanpercentile(xi_all, 5,  axis=0)
#
# NameError: name 'bins' is not defined

# %%
np.random.seed(42)

boxsize = 302600
bins = np.linspace(0.1, 1, 100) * boxsize
centers = 0.5 * (bins[:-1] + bins[1:])
n_repeat = 30

def count_pairs(points1, points2, bins):
    pair_counts = np.zeros(len(bins) - 1)
    for i in range(len(points1)):
        distances_sq = np.sum((points1[i] - points2) ** 2, axis=1)
        counts, _ = np.histogram(np.sqrt(distances_sq), bins=bins)
        pair_counts += counts
    return pair_counts

fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharex=True, sharey=True)

for ax, n_data in zip(axes, [1000, 10000]):
    n_random = 3 * n_data
    random_points = np.random.rand(n_random, 3) * boxsize
    nR = n_random

    rr = count_pairs(random_points, random_points, bins)
    rr = rr / (nR * (nR - 1) / 2)

    xi_all = []
    for k in range(n_repeat):
        idx = np.random.choice(len(pos), size=n_data, replace=False)
        data_points = pos[idx]
        nD = len(data_points)

        dd = count_pairs(data_points, data_points, bins)
        dr = count_pairs(data_points, random_points, bins)
        dd = dd / (nD * (nD - 1) / 2)
        dr = dr / (nD * nR)

        xi = np.zeros_like(dd, dtype=float)
        valid_bins = rr != 0
        xi[valid_bins] = (dd[valid_bins] - 2 * dr[valid_bins] + rr[valid_bins]) / rr[valid_bins]
        xi[~valid_bins] = np.nan
        xi_all.append(xi)

    xi_all = np.array(xi_all)
    xi_mean = np.nanmean(xi_all, axis=0)
    xi_lo = np.nanpercentile(xi_all, 5, axis=0)
    xi_hi = np.nanpercentile(xi_all, 95, axis=0)

    ax.fill_between(centers, xi_lo, xi_hi, alpha=0.3, label="5th–95th percentile")
    ax.plot(centers, xi_mean, "o-", label="mean", markersize=1)
    ax.axhline(0, color="gray", ls="--", lw=1)
    ax.set_xlabel("r [ckpc/h]")
    ax.set_title(f"2PCF: {n_repeat} resamples of {n_data} subhalos")
    ax.legend()

axes[0].set_ylabel(r"$\xi(r)$")
plt.tight_layout()
plt.savefig("tng300-1 2pcf comparison")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 28
#      26 xi_all = []
#      27 for k in range(n_repeat):
# ---> 28     idx = np.random.choice(len(pos), size=n_data, replace=False)
#      29     data_points = pos[idx]
#      30     nD = len(data_points)
#
# NameError: name 'pos' is not defined
